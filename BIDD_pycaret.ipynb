# %% [markdown]
# <a href="https://colab.research.google.com/github/ferdinand-popp/BIDD/blob/master/BIDD_pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --use-deprecated=legacy-resolver pycaret[full]

# %%
from pycaret.utils import enable_colab
enable_colab()
from pycaret.regression import *

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
dataset = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/data/bioactivity_final_data.csv')
data = dataset.loc[:, dataset.columns.difference(['canonical_smiles', 'standard_values', 'molecule_chembl_id'])]
data
# Out:
#         LogP       MW  ...     pIC50  standard_value
# 0    2.66050  421.190  ...  4.869666         13500.0
# 1    3.63080  293.347  ...  4.882397         13110.0
# 2    4.39330  372.243  ...  6.008774           980.0
# 3    4.23540  419.243  ...  6.022276           950.0
# 4    4.28420  327.792  ...  4.950782         11200.0
# ..       ...      ...  ...       ...             ...
# 114  3.40102  338.359  ...  4.974694         10600.0
# 115  3.44330  296.366  ...  4.995679         10100.0
# 116  4.09564  276.291  ...  4.939302         11500.0
# 117  3.29102  278.307  ...  4.970616         10700.0
# 118  4.10530  282.383  ...  4.102923         78900.0
#
# [119 rows x 7 columns]

# %%
exp1 = setup(data = data, target = 'standard_value', session_id=123, profile=True)

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-08-13 17:10:31--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-08-13 17:10:31--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# 2021-08-13 17:10:31 (195 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = dataset[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! bash padel.sh
# Out:
# Processing CHEMBL185698 in molecule.smi (1/119).
# Processing CHEMBL426082 in molecule.smi (2/119).
# Processing CHEMBL365134 in molecule.smi (3/119). Average speed: 2.23 s/mol.
# Processing CHEMBL190743 in molecule.smi (4/119). Average speed: 1.16 s/mol.
# Processing CHEMBL365469 in molecule.smi (5/119). Average speed: 0.98 s/mol.
# Processing CHEMBL188983 in molecule.smi (6/119). Average speed: 0.77 s/mol.
# Processing CHEMBL191575 in molecule.smi (7/119). Average speed: 0.74 s/mol.
# Processing CHEMBL370923 in molecule.smi (8/119). Average speed: 0.64 s/mol.
# Processing CHEMBL194398 in molecule.smi (9/119). Average speed: 0.63 s/mol.
# Processing CHEMBL196635 in molecule.smi (10/119). Average speed: 0.58 s/mol.
# Processing CHEMBL209287 in molecule.smi (11/119). Average speed: 0.58 s/mol.
# Processing CHEMBL348660 in molecule.smi (13/119). Average speed: 0.50 s/mol.
# Processing CHEMBL358279 in molecule.smi (12/119). Average speed: 0.53 s/mol.
# ...

# %%
! cd 'gdrive/MyDrive'
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 96
# -rw------- 1 root root 70334 Aug 12 19:00 bioactivity_data.csv
# -rw------- 1 root root 16217 Aug 12 19:20 bioactivity_final_data.csv
# -rw------- 1 root root 10578 Aug 12 19:01 bioactivity_preprocessed_data.csv

# %%
! ls -l
# Out:
# total 25416
# -rw-r--r-- 1 root root   222809 Aug 13 17:11 descriptors_output.csv
# drwx------ 5 root root     4096 Aug 13 17:10 gdrive
# drwxr-xr-x 3 root root     4096 Aug 13 17:10 __MACOSX
# -rw-r--r-- 1 root root     7186 Aug 13 17:10 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Aug 13 17:10 padel.sh
# -rw-r--r-- 1 root root 25768637 Aug 13 17:10 padel.zip
# drwxr-xr-x 1 root root     4096 Jul 16 13:20 sample_data

# %%
df3_X = pd.read_csv('descriptors_output.csv')
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 114           1           1  ...             0             0
# 115           1           1  ...             0             0
# 116           1           1  ...             0             0
# 117           1           1  ...             0             0
# 118           1           1  ...             0             0
#
# [119 rows x 881 columns]

# %%
df3_Y = dataset['pIC50']
df3_Y
# Out:
# 0      4.869666
# 1      4.882397
# 2      6.008774
# 3      6.022276
# 4      4.950782
#          ...
# 114    4.974694
# 115    4.995679
# 116    4.939302
# 117    4.970616
# 118    4.102923
# Name: pIC50, Length: 119, dtype: float64

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0             1           1           0  ...             0             0  4.869666
# 1             1           1           0  ...             0             0  4.882397
# 2             1           1           0  ...             0             0  6.008774
# 3             1           1           0  ...             0             0  6.022276
# 4             1           1           0  ...             0             0  4.950782
# ..          ...         ...         ...  ...           ...           ...       ...
# 114           1           1           1  ...             0             0  4.974694
# 115           1           1           1  ...             0             0  4.995679
# 116           1           1           0  ...             0             0  4.939302
# 117           1           1           0  ...             0             0  4.970616
# ...

# %%
dataset3.to_csv('final_set_for_model.csv', index=False)

# %%
! cp final_set_for_model.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %% [markdown]
# # Model Building

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/data/final_set_for_model.csv')
X = df.drop('pIC50', axis=1)
Y = df.pIC50
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 114           1           1  ...             0             0
# 115           1           1  ...             0             0
# 116           1           1  ...             0             0
# 117           1           1  ...             0             0
# 118           1           1  ...             0             0
#
# [119 rows x 881 columns]

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (119, 197)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.3669494954510667

# %%
Y_pred = model.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Lazy predict

# %%
! pip install lazypredict

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# ...
# 100%|██████████| 42/42 [00:00<00:00, 58916.64it/s]

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
